# %% [markdown]
# # Day 55/60 sickit-learn day 9
# # Support Vector Machine (SVM)

# %% [markdown]
# <H3>SVM: It is a type of Supervised Machine learning algorithm used in machine learning to solve classification and regression tasks.<br>
# and today we are gonna master SVM with Python and sickit-learn
# </H3>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Just a sample data

mean1 = 55
std_dev1 = 10
num_samples = 500

column1_numbers = np.random.normal(mean1, std_dev1, num_samples)
column1_numbers = np.clip(column1_numbers,30,120)
column1_numbers = np.round(column1_numbers).astype(int)

mean2 = 18
std_dev2 = 3

column2_numbers = np.random.normal(mean2, std_dev2,num_samples)
column2_numbers = np.clip(column2_numbers,12,26)
column2_numbers = np.round(column2_numbers).astype(int)

column3_numbers = np.random.randint(2, size = num_samples)
column3_numbers[column1_numbers > mean1] = 1

data = {'Miles Per Week' : column1_numbers,
        'Farthest_run' : column2_numbers,
        'Qualified_Boston_Marathon' : column3_numbers}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    Miles Per Week  Farthest_run  Qualified_Boston_Marathon
# 0              73            15                          1
# 1              56            19                          1
# 2              31            21                          0
# 3              46            21                          0
# 4              55            19                          1

# %%
# so I will be doing this work to see if the runners can qualify for the boston marathon or not

plt.figure(figsize = (10,6))
# lets use scatter plot
plt.scatter(df['Miles Per Week'], df['Farthest_run'], c = df['Qualified_Boston_Marathon'])
plt.xlabel("Miles Per Week")
plt.ylabel("Farthest_run")
plt.title("Scatter plot on Marathon Qualification")
plt.show()

# %%
X = df.iloc[:, 0:2]

# %%
y = df.iloc[:, 2]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test , y_train, y_test = train_test_split(X, y , random_state = 40, test_size = 0.2)

# %%
from sklearn.svm import SVC

# %%
model = SVC()

model.fit(X_train,y_train)
# Out:
# SVC()

# %%
model.score(X_test, y_test)
# Out:
# 0.7

# %%
#Regularization :techniques used to prevent overfitting in machine learning models.
model_reg0 = SVC(C=0.1)

# %%
model_reg0.fit(X_train,y_train)
# Out:
# SVC(C=0.1)

# %%
model_reg0.score(X_test, y_test)
# Out:
# 0.71

# %%
model_reg0 = SVC(C=0.1)
model_reg0.fit(X_train,y_train)
model_reg0.score(X_test, y_test)
# Out:
# 0.71

# %%
# gamma

# %%
model_gamma0 = SVC(gamma=0.1)
model_gamma0.fit(X_train,y_train)
model_gamma0.score(X_test, y_test)
# Out:
# 0.72

# %%
model_gamma0 = SVC(gamma=2)
model_gamma0.fit(X_train,y_train)
model_gamma0.score(X_test, y_test)
# Out:
# 0.75
